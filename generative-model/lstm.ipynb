# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("ai-guru/lakhclean_mmmtrack_4bars_d-2048")
model = AutoModelForCausalLM.from_pretrained("ai-guru/lakhclean_mmmtrack_4bars_d-2048")

# %%
import note_seq

BPM = 120
NOTE_LENGTH_16TH = 0.25 * 60 / BPM
BAR_LENGTH = 4.0 * 60 / BPM

def token_sequence_to_note_sequence(token_sequence, use_program=True, use_drums=True, instrument_mapper=None, only_piano=False):

    if isinstance(token_sequence, str):
        token_sequence = token_sequence.split()

    note_sequence = empty_note_sequence()

    # Render all notes.
    current_program = 1
    current_is_drum = False
    current_instrument = 0
    track_count = 0
    for token_index, token in enumerate(token_sequence):

        if token == "PIECE_START":
            pass
        elif token == "PIECE_END":
            print("The end.")
            break
        elif token == "TRACK_START":
            current_bar_index = 0
            track_count += 1
            pass
        elif token == "TRACK_END":
            pass
        elif token == "KEYS_START":
            pass
        elif token == "KEYS_END":
            pass
        elif token.startswith("KEY="):
            pass
        elif token.startswith("INST"):
            instrument = token.split("=")[-1]
            if instrument != "DRUMS" and use_program:
                if instrument_mapper is not None:
                    if instrument in instrument_mapper:
                        instrument = instrument_mapper[instrument]
                current_program = int(instrument)
                current_instrument = track_count
                current_is_drum = False
            if instrument == "DRUMS" and use_drums:
                current_instrument = 0
                current_program = 0
                current_is_drum = True
        elif token == "BAR_START":
            current_time = current_bar_index * BAR_LENGTH_120BPM
            current_notes = {}
        elif token == "BAR_END":
            current_bar_index += 1
            pass
        elif token.startswith("NOTE_ON"):
            pitch = int(token.split("=")[-1])
            note = note_sequence.notes.add()
            note.start_time = current_time
            note.end_time = current_time + 4 * NOTE_LENGTH_16TH_120BPM
            note.pitch = pitch
            note.instrument = current_instrument
            note.program = current_program
            note.velocity = 80
            note.is_drum = current_is_drum
            current_notes[pitch] = note
        elif token.startswith("NOTE_OFF"):
            pitch = int(token.split("=")[-1])
            if pitch in current_notes:
                note = current_notes[pitch]
                note.end_time = current_time
        elif token.startswith("TIME_DELTA"):
            delta = float(token.split("=")[-1]) * NOTE_LENGTH_16TH_120BPM
            current_time += delta
        elif token.startswith("DENSITY="):
            pass
        elif token == "[PAD]":
            pass
        else:
            #print(f"Ignored token {token}.")
            pass

    # Make the instruments right.
    instruments_drums = []
    for note in note_sequence.notes:
        pair = [note.program, note.is_drum]
        if pair not in instruments_drums:
            instruments_drums += [pair]
        note.instrument = instruments_drums.index(pair)

    if only_piano:
        for note in note_sequence.notes:
            if not note.is_drum:
                note.instrument = 0
                note.program = 0

    return note_sequence

def empty_note_sequence(qpm=120.0, total_time=0.0):
    note_sequence = note_seq.protobuf.music_pb2.NoteSequence()
    note_sequence.tempos.add().qpm = qpm
    note_sequence.ticks_per_quarter = note_seq.constants.STANDARD_PPQ
    note_sequence.total_time = total_time
    return note_sequence
# Out:
# c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
import os
from datasets import Dataset
# generate a dataset object for model training from the midi files in data by converting them into note sequences
dict_ = {"midi_ids": [], "note_sequences": []}
midi_id = 1
for file in os.listdir("../data/dataset/"):
    print(file)
    if file.endswith(".mid"):
        try:
            note_sequence = note_seq.midi_file_to_note_sequence(os.path.join("../data/dataset/", file))
            dict_["midi_ids"].append(midi_id)
            midi_id += 1
            dict_["note_sequences"].append(note_sequence)
        except:
            pass
# Out:
# 01dkc2bonus.mid
# 01DKC3_Bonus.mid
# 02dkc2&3-bonusfinished.mid
# 02main.mid
# 02snesDKC3_BossV1.1.mid
# 03dkc2boss.mid
# 03dkc3_bear.mid
# 04DKC3cavern.mid
# 04sento.mid
# 04snesDKC2_Boss.mid
# 05bramscrm.mid
# 05JILost_-_SNES_-_Donkey_Kong_Country_3_-_Baddies_on_Parade.mid
# c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# 06dkc2scram.mid
# 06DKC3Factory.mid
# 07dkc2bram.mid
# 07dkc3frst.mid
# 08ddt_gameover.mid
# 08DKQBrmbl.mid
# 09dkc3_gameover.mid
# 09SNES_DKC_Brambles.mid
# 1-01 Prelude Xg.mid
# 1-01-Liberi_Fatali.mid
# 1-02 - To Zanarkand (remix).mid
# 1-02 - To Zanarkand (version2).mid
# 1-02 - To Zanarkand (version3).mid
# 1-02 - To Zanarkand (version4).mid
# 1-02 - To Zanarkand (version5).mid
# 1-02 - To Zanarkand.mid
# 1-02 Opening ~ Bombing Mission Xg.mid
# 1-02-Balamb_Garden.mid
# 1-03 - Prelude (Draggor).mid
# 1-03 - Prelude (version2).mid
# 1-03 - Prelude (version3).mid
# 1-03 - Prelude.mid
# 1-03 Makou Reactor Xg.mid
# 1-03-Blue_Fields.mid
# 1-04 - Tidus.mid
# 1-04 - Tidus_Theme.mid
# 1-04 Anxious Heart Xg.mid
# 1-04-Dont_Be_Afraid.mid
# 1-05 - Otherworld (version2).mid
# 1-05 - Other_World.mid
# 1-05 Tifa's Theme Xg.mid
# 1-05-The_Winner.mid
# 1-06 Barett's Theme Xg.mid
# 1-06-Find_Your_Way.mid
# 1-07 - This is your Story (unsure).mid
# 1-07 Hurry! Xg.mid
# 1-07-Seed.mid
# 1-08 Lurking in the Darkness Xg.mid
# 1-08-The_Landing.mid
# 1-09 - Battle_Theme (version2).mid
# 1-09 - Battle_Theme.mid
# 1-09 ShinRa Company Xg.mid
# 1-09-Starting_Up.mid
# 1-10 - Gamover (version2).mid
# 1-10 - Victory.mid
# 1-10 - Victory_Fanfare.mid
# 1-10 Fighting Xg.mid
# 1-10-Force_Your_Way.mid
# 1-11 - Game_Over.mid
# 1-11 - Gamover (version2).mid
# 1-11 Fanfare Xg.mid
# 1-11-The_Loser.mid
# 1-12 - No Dream No Hope.mid
# 1-12 Flowers Blooming in the Church Xg.mid
# 1-12-Never_Look_Back.mid
# 1-13 Turk's Theme Xg.mid
# 1-13-Dead_End.mid
# 1-14 Underneath the Rotting Pizza Xg.mid
# 1-14-Breezy.mid
# 1-15 - Al_Bhed_Tribe's_Chi.mid
# 1-15 Opressed People Xg.mid
# 1-15-Shuffle_or_Boogie.mid
# 1-16 - Enemy Attack (version2).mid
# 1-16 - Enemy Attack (version3).mid
# 1-16 - Enemy Attack.mid
# 1-16 Honeybee Manor Xg.mid
# 1-16-Waltz_for_the_Moon.mid
# 1-17 - Blitz_Ball_Gamblers.mid
# 1-17 - Men Who Live for Blitz.mid
# 1-17 Who Are You Xg.mid
# 1-17-Tell_Me.mid
# 1-18 Don of the Slums Xg(1).mid
# 1-18-Fear.mid
# 1-19 - Scenery of Spira (version3).mid
# 1-19 - Scenery of Spira.mid
# 1-19 - Sight_of_Spira (version2).mid
# 1-19 Infiltrating ShinRa Tower Xg.mid
# 1-19-The_Man_With_the_Machine_Gun.mid
# 1-20 - Song of Prayer.mid
# 1-20 Still More Fighitng Xg.mid
# 1-20-Julia.mid
# 1-21 Red XIII's Theme Xg.mid
# 1-21-Roses_and_Wine.mid
# 1-22 - Cloister of Trials.mid
# 1-22 - Place_Of_Ordeals.mid
# 1-22 Crazy Motorcycle Xg.mid
# 1-22-Junction.mid
# 1-23 Holding My Thoughts in My Heart Xg.mid
# 1-23-Timber_Owls.mid
# 1-24 - Summoned (version2).mid
# 1-24 - Summoned.mid
# 1-25 - Daughter_of_High_Summoner.mid
# 10snesDKC3_HotPersuit.mid
# 10stickerbrush.mid
# 1100_am.mid
# 11dkc2cstl.mid
# 11dkc3purs.mid
# 1200_pm.mid
# 12Donkey.mid
# 12snesDKC3_K.Rool.mid
# 1300_pm.mid
# 13dkc2-ending.mid
# 13dkc3lakeside.mid
# 14dk3boat.mid
# 14dkc2enwd.mid
# 15dkc2fanfare.mid
# 15DKC3Pipe.mid
# 15epil.mid
# 16DKC2RarewareFanfareXG.mid
# 16DKC3_Swanky.mid
# 17dkc3tree.mid
# 17dkq-fanfare.mid
# 18Dkc2hntd.mid
# 18dkc3_treetop_rap.mid
# 19DKC2-_Haunted.mid
# 19snesDKC3_WaterfallV1.2.mid
# 2-01 - Yunas Theme (version2).mid
# 2-01 - Yunas_Theme.mid
# 2-01 FFVII Main Theme Xg.mid
# 2-01-My_Mind.mid
# 2-02 - Sprouting (version2).mid
# 2-02 - Sprouting.mid
# 2-02 Ahead on Our Way Xg.mid
# 2-02-The_Mission.mid
# 2-03 Good Night, Until Tommorow Xg.mid
# 2-03-Martial_Law.mid
# 2-04 - Silence_Before_The_Storm.mid
# 2-04 On That Day, 5 Years Ago Xg.mid
# 2-04-Cactus_Jack.mid
# 2-05 - Song of prayer - Ifrit.mid
# 2-05 Farm Boy Xg.mid
# 2-05-Only_A_Plank_Between_One_and_Perdition.mid
# 2-06 - Luca.mid
# 2-06 Waltz de Chocobo Xg.mid
# 2-06-Succession_of_Witches.mid
# 2-07 - Welcoming_Of_Maika_Elder_Sage.mid
# 2-07 Electric de Chocobo Xg.mid
# 2-07-Galbadia_Garden.mid
# 2-08 - Inflexible Determination.mid
# 2-08 - Inflexible Determination.txt
# 2-08 Cinco de Chocobo Xg.mid
# 2-08-Unrest.mid
# 2-09 - The Splendid Performance.mid
# 2-09 Chasing the Black-Caped Man Xg.mid
# 2-09-Under_Her_Control.mid
# 2-10 Fortress of the Condor Xg.mid
# 2-10-The_Stage_Is_Set.mid
# 2-11 - Blitz Off.mid
# 2-11 Rufus's Welcoming Ceremony Xg.mid
# 2-11-A_Sacrifice.mid
# 2-12 - Aruons Theme.mid
# 2-12 It's Difficult to Stand on Both Feet, Isn't It Xg.mid
# 2-12-Fithos_Lusec_Wecos_Vinosec.mid
# 2-13 - Mi'Ihen_Highway.mid
# 2-13 Trail of Blood Xg.mid
# 2-13-Intruders.mid
# 2-14 - Brass De Chocobo (version2).mid
# 2-14 - Brass_De_Chocobo.mid
# 2-14 J-E-N-O-V-A Xg.mid
# 2-14-Premonition.mid
# 2-15 Conitnue Xg.mid
# 2-15-Wounded.mid
# 2-16 - Permission to Pass.mid
# 2-16 Costa Del Sol Xg.mid
# 2-16-Fragments_of_Memories.mid
# 2-17 - Seymour's_Theme.mid
# 2-17 Mark of the Traitor Xg.mid
# 2-17-Jailed.mid
# 2-18 Mining Town Xg.mid
# 2-18-Rivals.mid
# 2-19 - Djoze temple.mid
# 2-19 Gold Saucer Xg.mid
# 2-19-Ami.mid
# 2-20 - Song of prayer - Ixion.mid
# 2-20 Cait Sith's Theme Xg.mid
# 2-21 - Ride the Ciparph.mid
# 2-21 Sandy Badlands Xg.mid
# 2-22 - Rikku's theme (playful).mid
# 2-22 - Rikku's theme (version2).mid
# 2-22 - Rikku's theme (version3).mid
# 2-22 - Rikku.mid
# 2-22 - Rikkus Theme (version2).mid
# 2-22 - Rikku_Mix.mid
# 20dkc3watr.mid
# 20dkciiice.mid
# 21DKC2Ice-GM.mid
# 21Wsc-ex-c.mid
# 22DKC2Ice.mid
# 22Wsc-enh.mid
# 23DKC2IceCaveByCryogen.mid
# 24snesDKC2_MapV1.2.mid
# 25Islandmap_1.mid
# 26dkc2_map_remix.mid
# 27dkc2junglegoal.mid
# 28dkc2Klba.mid
# 29dkc2klubba.mid
# 3-01 - Thunder Plains (version2).mid
# 3-01 - Thunder Plains.mid
# 3-01 - Thunder_Plateau.mid
# 3-01 Cosmo Canyon Xg.mid
# 3-01-The_Spy.mid
# 3-02 Life Stream Xg.mid
# 3-02-Retaliation.mid
# 3-03 Great Warrior Xg.mid
# 3-03-Movin.mid
# 3-04 Descendant of Shinobi Xg .mid
# 3-04-Blue_Sky.mid
# 3-05 Those Chosen by the Planet Xg .mid
# 3-05-Drifting.mid
# 3-06 - Seymours Ambition (version2).mid
# 3-06 - Seymours Ambition.mid
# 3-06 The Nightmare's Beginning Xg.mid
# 3-06-Heresy.mid
# 3-07 - Song of prayer - Shiva.mid
# 3-07 Cid's Theme Xg.mid
# 3-07-Fishermans_Horizon.mid
# 3-08 Steal the Tiny Bronco! Xg.mid
# 3-08-Odeka_de_Chocobo.mid
# 3-09 Wutai Xg.mid
# 3-09-Where_I_Belong.mid
# 3-10 Stolen Materia Xg.mid
# 3-10-The_Oath.mid
# 3-11 Racing Chocobos-Place Your Bets Xg.mid
# 3-11-Slide_Show_Part_1.mid
# 3-12 Fiddle de Chocobo Xg.mid
# 3-12-Slide_Show_Part_2.mid
# 3-13 A Great Success Xg.mid
# 3-13-Love_Grows.mid
# 3-14 - Attack (version2).mid
# 3-14 - Attack (version3).mid
# 3-14 - Attack.mid
# 3-14 Tango of Tears Xg.mid
# 3-14-The_Salt_Flats.mid
# 3-15 Debut Xg.mid
# 3-15-Trust_Me.mid
# 3-16 - I Can Fly (version2).mid
# 3-16 - I Can Fly.mid
# 3-16 Interupted by Fireworks Xg.mid
# 3-16-Silence_and_Motion.mid
# 3-17 - Path of Repentance (extended).mid
# 3-17 - Path_Of_Repentance.mid
# 3-17 Forested Temple Xg.mid
# 3-17-Dance_With_the_Balamb_Fish.mid
# 3-18 - Song of prayer - Bahamut.mid
# 3-18 You Can Hear the Cry of the Planet Xg.mid
# 3-18-Tears_of_the_Moon.mid
# 3-19 Aerith's Theme Xg.mid
# 3-19-Residents.mid
# 3-20 - My_Father's_Murderer.mid
# 3-20 Buried in the Snow Xg.mid
# 3-20-Eyes_On_Me.mid
# 3-20-Eyes_On_Me_2.mid
# 3-21 - Suteki Da Ne (Isn't It Wonderful).mid
# 3-21 - Suteki da Ne (remix).mid
# 3-21 - Suteki da Ne (version2).mid
# 3-21 - Suteki da Ne (version3).mid
# 3-21 - Suteki da Ne (version4).mid
# 3-21 The Great Northern Cave Xg.mid
# 3-22 Reunion Xg.mid
# 3-23 Who Am I Xg.mid
# 30dkc2krl.mid
# 31DKQLava.mid
# 32dkc2lavags.mid
# 33dkc2lava.mid
# 34dkc2lav2.mid
# 35DKC2_Lava.mid
# 36LostWorld.mid
# 37DKC2Mine.mid
# 38mine.mid
# 39DKQMine.mid
# 3battle1.mid
# 3battle2.mid
# 3cryscave.mid
# 3darkcrys.mid
# 3elia.mid
# 3eterwind.mid
# 3everlasting.mid
# 3forbidden.mid
# 3gysahl.mid
# 3hyne.mid
# 3invincible.mid
# 3jinn.mid
# 3lastbatt.mid
# 3lute.mid
# 3ocean.mid
# 3prelude.mid
# 3requiem.mid
# 3salonia.mid
# 3tower.mid
# 3town.mid
# 3townwater.mid
# 3tozas.mid
# 3truth.mid
# 4-01 - Yunas Determination.mid
# 4-01 - Yunas_Determination.mid
# 4-01 ShinRa Army Wages a Full Scale Attack Xg .mid
# 4-01-Mods_de_Chocobo.mid
# 4-02 - Lulus Theme.mid
# 4-02 Weapon Raid Xg.mid
# 4-02-Ride_On.mid
# 4-03 - Brave Advancement (version2).mid
# 4-03 - Brave_Advancement.mid
# 4-03 Highwind Takes to the Skies Xg.mid
# 4-03-Truth.mid
# 4-04 A Secret, Sleeping in the Deep Sea Xg .mid
# 4-04-Lunatic_Pandora.mid
# 4-05 - People of the North (version2).mid
# 4-05 - People_Of_The_North_Pole.mid
# 4-05 Parochial Town Xg.mid
# 4-05-Compression_of_Time.mid
# 4-06 Off the Edge of Dispair Xg.mid
# 4-06-The_Castle.mid
# 4-07 - Wandering_Flames.mid
# 4-07 On the Other Side of the Mountain Xg.mid
# 4-07-The_Legendary_Beast.mid
# 4-08 - Someday the Dream Will End.mid
# 4-08 - Someday_The_Dream_Will_End (version2).mid
# 4-08 - Someday_The_Dream_Will_End.mid
# 4-08 Hurry Faster! Xg.mid
# 4-08-Maybe_Im_a_Lion.mid
# 4-09 Sending a Dream Into the Universe Xg.mid
# 4-09-The_Extreme.mid
# 4-10 The Countdown Begins Xg.mid
# 4-10-The_Successor.mid
# 4-11 If You Open Your Heart___ Xg.mid
# 4-11-Ending_Theme.mid
# 4-12 The Makou Cannon is Fired ~ ShinRa Explodes Xg.mid
# 4-12-Overture.mid
# 4-13 Judgement Day Xg.mid
# 4-14 - The Dead Still Smile.mid
# 4-14 Jenova Absolute Xg.mid
# 4-15 - Seymours Battle (version2).mid
# 4-15 - Seymour_Battle.mid
# 4-15 The Birth of God Xg.mid
# 4-16 One Winged Angel Xg.mid
# 4-17 - Summoned Beast Battle (extended).mid
# 4-17 - Summoned_Beast_Battle (version2).mid
# 4-17 - Summoned_Beast_Battle.mid
# 4-17 World Crisis Xg.mid
# 4-18 - Decisive_Battle.mid
# 4-18 Staff Roll Xg.mid
# 4-19 - Ending.mid
# 4-19 - Ending_Theme (version2).mid
# 4-19 - Ending_Theme.mid
# 4.17 - Summoned_Monster_Battle.mid
# 40DKC2Mine-V1.1.mid
# 41mineremix.mid
# 42DKC_RMX_V1.1_(Mine_LVL).mid
# 43dk2riggn.mid
# 44DKC2JibJigDeathXG.mid
# 45dkc2-roller_coaster.mid
# 46Krazy_Kremland.mid
# 47DKC2_Roller_Coaster_V1_1_XG.mid
# 48DKC2DiscoDeathXG.mid
# 49snesRambi_RumbleV1.1.mid
# 4boss.mid
# 4final.mid
# 4password.mid
# 4select.mid
# 50Escape_from_King_Zing.mid
# 51rattle.mid
# 52dkc2abc.mid
# 53snesDkc2_Ship_Deck_Goal.mid
# 54dkc2shiphold.mid
# 55Lockjaw_s_Locker.mid
# 56Lockjaws_Saga.mid
# 57SwampV2.mid
# 58dk2swank.mid
# 59DKC2_SwankyKong_Remix.mid
# 5intro.mid
# 5wily.mid
# 5wily1.mid
# 60KS_dkc2_swanky_XG.mid
# 61dkc2hive.mid
# 62dkc2-wasphive.mid
# 63dk2wasp.mid
# 64dkcwrink.mid
# 64title.mid
# 6intro.mid
# 6wily1.mid
# 7end.mid
# 7intro.mid
# 7intro2.mid
# 7wily.mid
# 8drl.mid
# 8end2.mid
# 8intro.mid
# 8notend.mid
# 8select.mid
# 8select2.mid
# 8select3.mid
# 8wily2.mid
# a-FF8battle-theme.mid
# able_sisters.mid
# ageslev2.mid
# Alexandria.mid
# alloy_warrior.mid
# all_star_introduction.mid
# all_star_introduction_2.mid
# Aloha_del_Chocobo.mid
# Amanda.mid
# Amarant.mid
# ambush_attack.mid
# angry_aztec_remix.mid
# aqua-remix.mid
# aquaman.mid
# aquatic.mid
# astroman.mid
# At_Zanarkand_(Ameliorated).mid
# At_Zanarkand_(Child_&_Parents_Remix).mid
# autoroll.mid
# a_night_in_alexandria.mid
# balloon_fight.mid
# banana_fairy_island.mid
# bass.mid
# battle.mid
# Battle_Theme.mid
# Battle_Theme2.mid
# Battle_Theme_1.mid
# battle_theme_piano.mid
# beat_a_boss.mid
# Behind_the_door.mid
# Bittersweet_Romance.mid
# black_mage_village.mid
# Black_waltz.mid
# blast_hornet.mid
# blaze_phoenix.mid
# blizzardman.mid
# blizzardman2.mid
# blizzard_buffalo2.mid
# boss-z2.mid
# boss.mid
# Boss_Battle.mid
# boss_intro.mid
# boss_theme.mid
# boundary_south_gate.mid
# bowswrld.mid
# brambles.mid
# BRAMBNES.MID
# Bremen_mask.mid
# brightman.mid
# brinstar_theme.mid
# brinstar_theme_2.mid
# burstman.mid
# C4-clear.mid
# c4beginning.mid
# C4castlemap.mid
# C4cave.mid
# C4caves.mid
# C4clocktwrmap.mid
# C4domaingate.mid
# C4domainmap.mid
# C4drctowermap.mid
# c4final.mid
# C4gameover.mid
# C4password.mid
# CASTLEFX.MID
# castlevania-cavecomplete.mid
# CastleVania-_Illusions.mid
# CastleVania-_Maze.mid
# castlevania.mid
# Castlevania4-Cellar(stage8)V2.mid
# cave.mid
# cavedweller.mid
# caveunder.mid
# CBFourside-Accurate.mid
# centaurman.mid
# centaurman2.mid
# Chandaliers.mid
# character_select.mid
# chargeman.mid
# chargeman2.mid
# Chosen_summoner.mid
# cleyra_settlement.mid
# ClockworkMansion.mid
# Clock_tower.mid
# Clock_town.mid
# cloudman.mid
# clownman.mid
# cmed.mid
# cmed2.mid
# Conde_Petit.mid
# consecutive_battles.mid
# corneria_theme.mid
# corneria_theme_2.mid
# corneria_theme_3.mid
# cossac.mid
# cossac2.mid
# crossing_the_knoll.mid
# crush_crawfish.mid
# crystalman.mid
# crystal_caves_lobby.mid
# crysyal world.mid
# cv1-boss.mid
# cv1-d1st.mid
# cv1-d2nd.mid
# cv1-end.mid
# cv1-st1.mid
# cv1-st2.mid
# cv1-st3.mid
# cv1-st4.mid
# cv1-st5.mid
# cv1-st6.mid
# cv4-1.mid
# Cv4-st2.mid
# Cv4-st51.mid
# CV4-_Level_6B.mid
# CV4-_Level_7.mid
# CV4-_Level_9.mid
# CV4-_Theme_of_Simon.mid
# CV4-_Vampire_Killer.mid
# Cv4Cast.mid
# cv4s4a.mid
# cv4s4b.mid
# cv4st51r.mid
# cvend.mid
# cvintro.mid
# cvlevel2.mid
# cvlevel3.mid
# cvlevel4.mid
# cvlevel5.mid
# cvlevel6.mid
# cvlevl12.mid
# cvlevl13.mid
# cvlevl22.mid
# cvlevl32.mid
# cvlevl42.mid
# cvlevl52.mid
# cvlevl62.mid
# cvlevl63.mid
# cvs_01_tower_of_mist.mid
# cvs_04_moonlight_nocturne.mid
# cvs_05_prayer.mid
# cvs_06_draculas_castle2.mid
# cvs_06_draculas_castle3.mid
# cvs_06_draculas_castle_remix.mid
# cvs_08_marble_gallery_remix.mid
# cvs_08_marble_gallery_remix2.mid
# cvs_15_requiem_for_the_gods.mid
# cvs_18_rainbow_cemetery.mid
# cvs_20_lost_painting.mid
# cvs_20_lost_painting2.mid
# cvs_20_lost_painting3.mid
# cvs_21_dance_of_pales.mid
# cvs_21_dance_of_pales2.mid
# cvs_24_wandering_ghosts.mid
# cvs_24_wandering_ghosts_remix.mid
# cvs_25_tragic_prince.mid
# cvs_29_blood_relations.mid
# Dali.mid
# Dance_of_Pales.mid
# Danger_in_the_forest.mid
# Dawn.mid
# daytime.mid
# daytime2.mid
# daytime3.mid
# daytime_remix.mid
# Defeatdracula.mid
# Deku_palace.mid
# depths_of_brinstar.mid
# didn't_capture_the_hearts_of_both.mid
# Dissipating_Magic.mid
# dissipating_sorrow.mid
# diveman.mid
# dk2sticker.mid
# dk3waterfall.mid
# dkbonuslose.mid
# Dkc08aquaticambiance.mid
# dkc3frostyfrolics.mid
# dkc3rockt.MID
# dkc3Water.mid
# Dkc3_mount.mid
# dkcamb.mid
# dkcambiance.mid
# dkccoral.mid
# dkccrank.mid
# dkcjung.mid
# dkckrool1.mid
# dkcoil1.mid
# dkcsnow.mid
# dkctheme.mid
# dkcwaterlevel.mid
# dkcwink.mid
# dkc_aqua_ambiance.mid
# dkc_ice_cave.mid
# dkmt.mid
# dktree.mid
# dk_isle.mid
# dk_isle_remix.mid
# dk_lobby.mid
# donkey_kong_wins.mid
# doom_castle_theme_remix.mid
# doppler1.MID
# dracula4.mid
# drcain.mid
# dream_land.mid
# drillman.mid
# drlight.mid
# dr_mario.mid
# dr_mario_2.mid
# dr_mario_3.mid
# dr_mario_4.mid
# dr_mario_arranged.mid
# dr_mario_remix.mid
# dungeon1.mid
# dungeon2.mid
# dungeon3.mid
# dungeon4.mid
# dungeon5.mid
# dungeon6.mid
# dungeon7.mid
# dungeon8.mid
# dungeon9.mid
# dustman.mid
# EarthBound.mid
# Earthbound_Hotel_(Huzzah_Remix).mid
# Earth_gods_lyric.mid
# ebcredits.mid
# ebfinalbattle.mid
# ebgiygas.mid
# ebhippie.mid
# ebnesshouse.mid
# ebnesshouse2.mid
# ebsatvly.mid
# ebsnowschool.mid
# ebthreed2.mid
# ebtwoson.mid
# ebwinter.mid
# eb_bus.mid
# eb_hotel.mid
# eb_onett.mid
# eb_store.mid
# eb_thred.mid
# Eikos_Theme.mid
# ending.mid
# ending2.mid
# ending_theme.mid
# Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Esto_Gaza.mid
# Eternal_Harvest (Cleira_dance).mid
# everdred.mid
# fairy battle.mid
# Fanfare.mid
# fantic_factory_remix.mid
# Far_Away_Twilight.mid
# Feel_My_Blade (theatre_battle).mid
# FF10_Battle (demo battle).mid
# FF10_The_Real_Battle_Piano.mid
# FF11_04_Ronfaure.mid
# FF11_08_The_Republic_of_Bastok.mid
# FF11_14_Sarutabaruta.mid
# FF11_35_Recollection.mid
# FF11_37_Battle_in_the_Dungeon_2.mid
# FF11_51_Vandiel_March_2.mid
# ff12_prelude.mid
# ff12_theme.mid
# FF1airsh.mid
# FF1battl.mid
# FF1castl.mid
# FF1cave.mid
# FF1chaos.mid
# FF1epilo.mid
# FF1float.mid
# FF1gurgu.mid
# FF1matou.mid
# FF1menu.mid
# FF1prelu.mid
# FF1prolo.mid
# FF1ship.mid
# FF1shop.mid
# FF1slain.mid
# FF1town.mid
# FF1under.mid
# FF1world.mid
# FF2battl.mid
# FF2cashu.mid
# FF2castl.mid
# FF2epilo.mid
# FF2slain.mid
# FF2town.mid
# FF2world.mid
# FF4airsh.mid
# FF4bab-i.mid
# FF4baron.mid
# FF4battl.mid
# FF4betra.mid
# FF4bigwh.mid
# FF4boss.mid
# FF4calbr.mid
# FF4cave.mid
# FF4choco.mid
# FF4cid.mid
# FF4cryst.mid
# FF4dance.mid
# FF4dwarf.mid
# FF4eblan.mid
# FF4edwar.mid
# FF4elder.mid
# FF4epilo.mid
# FF4evil.mid
# FF4fabul.mid
# FF4fiend.mid
# FF4fores.mid
# FF4golbe.mid
# FF4lcave.mid
# FF4lsubt.mid
# FF4moon.mid
# FF4mtord.mid
# FF4mysid.mid
# FF4prolo.mid
# FF4redwi.mid
# FF4rosa.mid
# FF4rydia.mid
# FF4sorro.mid
# FF4surpr.mid
# FF4sylva.mid
# FF4toroi.mid
# FF4town.mid
# FF4under.mid
# FF4victo.mid
# FF4world.mid
# FF4zerom.mid
# FF4zot.mid
# FF6_01_Opening_Theme.mid
# FF6_02_The_Mines_of_Narshe.mid
# FF6_03_Awakening.mid
# FF6_03_Awakening_(Version_2).mid
# FF6_04_Lockes_Theme.mid
# FF6_04_Lockes_Theme_(Version_2).mid
# FF6_04_Lockes_Theme_(Version_3).mid
# FF6_05_Battle_Theme.mid
# FF6_05_Battle_Theme_2.mid
# FF6_06_Fanfare.mid
# FF6_07_Edgar_and_Sabin.mid
# FF6_08_Kefka.mid
# FF6_08_Kefkas_Theme_2.mid
# FF6_09_Mt_Koltz.mid
# FF6_10_Returners.mid
# FF6_11_Shadows_Theme.mid
# FF6_11_Shadow_2.mid
# FF6_12_Troops_March_On.mid
# FF6_13_Cyans_Theme.mid
# FF6_14_Unforgiven.mid
# FF6_15_Phantom_Forest_2.mid
# FF6_15_The_Phantom_Forest.mid
# FF6_16_The_Phantom_Train.mid
# FF6_17_Wild_West.mid
# FF6_18_Gaus_Theme.mid
# FF6_19_The_Serpent_Trench.mid
# FF6_20_Kids_Run_Trough_the_City.mid
# FF6_20_Kids_Run_Trough_the_City_2.mid
# FF6_21_Under_Martial_Law.mid
# FF6_22_Celes_2.mid
# FF6_22_Celes_Theme.mid
# FF6_23_Save_Them.mid
# FF6_24_The_Decisive_Battle.mid
# FF6_24_The_Decisive_Battle_2.mid
# FF6_25_Metamorphosis.mid
# FF6_25_Metamorphosis_2.mid
# FF6_26_Terra.mid
# FF6_26_Terra_2.mid
# FF6_26_Terra_3.mid
# FF6_27_Coin_Song.mid
# FF6_28_Techno_de_Chocobo.mid
# FF6_28_Techno_de_Chocobo_2.mid
# FF6_29_Forever_Rachel.mid
# FF6_29_Forever_Rachel_2.mid
# FF6_30_Slam_Shuffle.mid
# FF6_30_Slam_Shuffle_2.mid
# FF6_31_Spinach_Rag.mid
# FF6_32_Overture.mid
# FF6_32_Overture_2.mid
# FF6_33_Aria_de_Mezzo.mid
# FF6_34_The_Wedding.mid
# FF6_35_Grand_Finale.mid
# FF6_35_Grand_Finale_2.mid
# FF6_36_Setzer.mid
# FF6_36_Setzer_2.mid
# FF6_37_Johnny_C_Bad.mid
# FF6_38_Emperor_Gestahl.mid
# FF6_39_Devil_Lab.mid
# FF6_40_Blackjack.mid
# FF6_41_Unknown.mid
# FF6_42_Mog.mid
# FF6_43_Stragos.mid
# FF6_44_Relm.mid
# FF6_45_Another_World_of_Beasts.mid
# FF6_45_Another_World_of_Beasts_2.mid
# FF6_46_New_Continent.mid
# FF6_46_New_Continent_2.mid
# FF6_47_Catastrophe.mid
# FF6_48_The_Fierce_Battle.mid
# FF6_48_The_Fierce_Battle_2.mid
# FF6_49_Rest_in_Peace.mid
# FF6_50_Dark_World.mid
# FF6_51_The_Day_After.mid
# FF6_52_Searching_for_Friends.mid
# FF6_53_Gogo.mid
# FF6_54_Epitaph.mid
# FF6_54_Epitaph_2.mid
# FF6_55_The_Magic_House.mid
# FF6_56_Umaro.mid
# FF6_57_Fanatics.mid
# FF6_58_Last_Dungeon.mid
# FF6_59_Dancing_Mad.mid
# FF6_59_Dancing_Mad_2.mid
# FF6_59_Dancing_Mad_3.mid
# FF6_59_Dancing_Mad_4.mid
# FF6_59_Dancing_Mad_5.mid
# FF6_60_Ending_Theme.mid
# FF6_60_Ending_Theme_2.mid
# FF6_61_The_Prelude.mid
# FF6_61_The_Prelude_2.mid
# ffa2ndoverworld.mid
# ffaboss.mid
# ffaboss2.mid
# ffactory1.mid
# FFAdventure.mid
# ffadwa.mid
# ffafiel2.mid
# ffafield.mid
# ffalb.mid
# ffalb2.mid
# ffalest.mid
# ffamissn.mid
# ffaoverworld2.mid
# ffapart.mid
# ffatempl.mid
# Ffatitle.mid
# ffatwn1.mid
# ffa_bt2.mid
# FFCC_across.mid
# FFCC_annual_festival.mid
# FFCC_boss.mid
# FFCC_caravan_crossroad.mid
# FFCC_desert.mid
# FFCC_ending.mid
# FFCC_freedom.mid
# FFCC_gameover.mid
# FFCC_kakugo.mid
# FFCC_last_boss.mid
# FFCC_lifewater.mid
# FFCC_moving_clouds_on_the_rivers_surface.mid
# FFCC_musicbox.mid
# FFCC_simasima.mid
# FFCC_tabidati.mid
# FFCC_thipa.mid
# FFCC_toride.mid
# FFCC_uruoi.mid
# FFCC_worldmap.mid
# FFCC_yasuragi.mid
# ffl1bat.mid
# ffl1tow.mid
# ffl1_bt1.mid
# ffl1_op.mid
# fflband.mid
# FFLCloud.mid
# fflcrea2.mid
# fflcreat.mid
# ffl_perished.mid
# ffl_sadtheme.mid
# ffmqaqua.mid
# ffmqbatl.mid
# ffmqboss.mid
# ffmqfcus.mid
# ffmqfire.mid
# ffmqfnl.mid
# ffmqhill.mid
# ffmqlast.mid
# ffmqlf.mid
# ffmqmine.mid
# ffmqmtn.mid
# ffmqpazu.mid
# ffmqtris.mid
# ffmqvolc.mid
# FFX-Hymn_of_the_Fayth.mid
# FFX_Prelude_Remix.mid
# FFX_Trailer.mid
# fighting_intro.mid
# finale.mid
# fire_emblem.mid
# fire_emblem_2.mid
# flameman.mid
# flameman2.mid
# flat_zone.mid
# forest_frenzy.mid
# Forest_haven.mid
# Forgotten_Face (Freija_theme).mid
# forgotten_memory_in_the_storm.mid
# fortress.mid
# Fossil_Roo.mid
# fountain_of_dreams.mid
# fountain_of_dreams_2.mid
# fountain_of_dreams_3.mid
# fountain_of_dreams_4.mid
# fourside.mid
# fourside1.mid
# fox_wins.mid
# frantic_factory.mid
# frostman.mid
# fungi_forest_day.mid
# fungi_forest_day2.mid
# fungi_forest_day_3.mid
# fungi_forest_lobby.mid
# gameboy_super-ma_overworld.mid
# gameboy_super-ma_ruins.mid
# gameover.mid
# gameoversmw.mid
# Game_Over.mid
# gargan_roo.mid
# garnets_theme.mid
# Gate_Theme_v1_2.mid
# Gate_V3_1.mid
# Ghizamaluk.mid
# Gidan.mid
# gloomy_galleon.mid
# Goodnight.mid
# gravityman.mid
# gravityman2.mid
# gravity_beetle.mid
# gravity_beetle_2.mid
# Great_bay.mid
# gulgu_volcano.mid
# gyroman.mid
# hammer.mid
# hauntedhouse.mid
# Heaven_Distress.mid
# HildaGardeIII.mid
# hit_the_targets.mid
# hospital.mid
# HotPursuit.mid
# Hunter_Chance.mid
# hyrule_temple_remix.mid
# hyrule_temple_remix_2.mid
# hyrule_temple_remix_3.mid
# hyrule_temple_remix_4.mid
# hyrule_temple_remix_5.mid
# hyrule_temple_theme.mid
# icecavern.mid
# ice_climbers_wins.mid
# icicle_mountain.mid
# icicle_mountain_2.mid
# idiotseag.mid
# Iifa_tree.mid
# Illusia.mid
# Immoral_Melody (Angelofdeath).mid
# InfinityMijinion.mid
# inside_the_mansions.mid
# inside_the_towns.mid
# Intro.mid
# introstage.mid
# intro_music.mid
# invincibility.mid
# janitor_of_time.mid
# jema.mid
# Jesters_of_the_Moon (SonZon_theme).mid
# jozai.mid
# Jump Festival.mid
# Jump XMAS.mid
# jungle.mid
# jungle_japes_remix.mid
# kakariko.mid
# kirby_wins.mid
# kk_ballad.mid
# kk_condor.mid
# kk_country.mid
# kk_lovesong.mid
# kk_rider.mid
# kk_slider_rock.mid
# kk_song.mid
# knightman.mid
# knightman2..mid
# kongfused.mid
# koopabattle.mid
# KRAKEN.mid
# Kujas_theme.mid
# k_lumsy.mid
# lakesidenes.mid
# lastempl.mid
# last_battle.mid
# let_the_heart_sing_with_the_melody.mid
# level-2.mid
# Level3-2.mid
# Level3-2Win.mid
# Level3.mid
# Level3Win.mid
# level9-1.mid
# level9-2.mid
# level9remix.mid
# levelend.mid
# Lindblum.mid
# Lindblum_Castle.mid
# link_wins.mid
# llimbodk3.mid
# Locke_2.mid
# loss_of_me1.mid
# Loss_of_Me2.mid
# Loss_of_Me3.mid
# lost_caves.mid
# m1_underground.mid
# M3water.mid
# m64bomb.mid
# m64bowsr.mid
# m64crs1.mid
# m64crse1.mid
# m64docks.mid
# m64endin.mid
# m64file.mid
# m64metal.mid
# m64metlm.mid
# m64slide.mid
# m64snow.mid
# m64vansh.mid
# m64water.mid
# m64wings.mid
# Mana_Tree[1].mid
# marioworldjazzguitar.mid
# mario_wins.mid
# marth_wins.mid
# master_hand_battle.mid
# mavdopp.mid
# maverick_defeat.mid
# mcmadness.mid
# medley.mid
# megaman_x5.mid
# Mega_Man_X5-Rangda_Bangda_II.mid
# melodies_of_life.mid
# Melodies_of_Life2.mid
# memoria.mid
# Menu.mid
# MenuWin.mid
# menu_screens.mid
# mermaid__s_palace.mid
# mill.mid
# minecartmadness.mid
# minecartpiano.mid
# misty.mid
# mk64-awards.mid
# mk64-desert.mid
# mk64-frappe.mid
# mk64-rr.mid
# mk64-rrer1.mid
# mk64-rrer2.mid
# mk64credits.mid
# mk64mraceway.mid
# mk64rain2.mid
# mk64sherbet.mid
# mk64star.mid
# mk64_blockfort.mid
# mk64_bowser.mid
# mk64_ktb.mid
# mm1bomb.mid
# mm1bomb2.mid
# mm1cut.mid
# mm1elec.mid
# mm1end.mid
# mm1fire.mid
# mm1guts.mid
# mm1ice.mid
# mm1mast.mid
# mm1wily1.mid
# mm1wily2.mid
# mm2air.mid
# mm2boss.mid
# mm2bubbl.mid
# mm2cras2.mid
# mm2crash.mid
# mm2end.mid
# mm2flas2.mid
# mm2flash.mid
# mm2heat.mid
# mm2intro.mid
# mm2meta2.mid
# mm2metal.mid
# mm2passw.mid
# mm2quick.mid
# mm2selec.mid
# mm2titl2.mid
# mm2title.mid
# mm2w1rm.mid
# mm2wily1.mid
# mm2wood.mid
# mm2wy1.mid
# mm3-int.mid
# mm3gemi2.mid
# mm3gemin.mid
# mm3hard.mid
# mm3intr2.mid
# mm3intro.mid
# mm3magnt.mid
# mm3needl.mid
# mm3passw.mid
# mm3proto.mid
# mm3protw.mid
# mm3selct.mid
# mm3shad2.mid
# mm3shado.mid
# mm3snake.mid
# mm3spar2.mid
# mm3spark.mid
# mm3top.mid
# mm3top2.mid
# mm3weprc.mid
# mm3wily1.mid
# mm4intp2.mid
# mmx-hwin.mid
# mmx1eagle.mid
# mmx1select.mid
# mmx6gate.mid
# mmx6sigmabattle1.mid
# mmxarma2.mid
# mmxarmd.mid
# mmxbattf.mid
# mmxbatti.mid
# mmxcaps.mid
# mmxcham.mid
# mmxcham2.mid
# mmxchil2.mid
# mmxchirm.mid
# mmxeagl.mid
# mmxend.mid
# mmxendg.mid
# mmxequip.mid
# mmxf1.mid
# mmxf2.mid
# mmxf3.mid
# mmxf4.mid
# mmxhcred.mid
# mmxintro.mid
# mmxkuwa2.mid
# mmxkuwan.mid
# mmxlbatt.mid
# mmxmamm2.mid
# mmxmamt.mid
# mmxmand.mid
# mmxmavin.mid
# mmxmbatt.mid
# mmxmend.mid
# mmxmsel.mid
# mmxocean.mid
# mmxoct2.mid
# mmxpass.mid
# mmxpass2.mid
# mmxpeng.mid
# mmxprog.mid
# mmxsf1.mid
# mmxsf2.mid
# mmxsf3.mid
# mmxsf4.mid
# mmxsgm2.mid
# mmxsig1.mid
# mmxsig2.mid
# mmxsprk2.mid
# mmxsprk3.mid
# mmxsref.mid
# mmxssel.mid
# mmxssel2.mid
# mmxstat.mid
# mmxtitl2.mid
# mmxvile.mid
# mmxvilei.mid
# mmxwepn2.mid
# mmxzero.mid
# mmxzero2.mid
# mmxzero3.mid
# mmxzero4.mid
# mood_point_tally.mid
# museum.mid
# mushroom_kingdom.mid
# mushroom_kingdom_2.mid
# mushroom_kingdom_finale.mid
# mute_city.mid
# mute_city_2.mid
# mwcave.mid
# mwcst.mid
# Mystery_Sword.mid
# napalmman.mid
# neon_tiger.mid
# ness_wins.mid
# ness_wins_2.mid
# ness_wins_3.mid
# nighttime.mid
# onett_theme.mid
# One_problem_settled.mid
# only_me.mid
# Outset_island.mid
# overworld.mid
# overworld1.mid
# overworld2.mid
# overworld3.mid
# Overworld_theme.mid
# OW1.mid
# p-box.mid
# Pandemonium.mid
# password_music.mid
# pause.mid
# pharoahman.mid
# pianorain.mid
# pianounder.mid
# pipe.mid
# plantman.mid
# pokemon_stadium_theme.mid
# police_station.mid
# prelude.mid
# Prima_Vista_band.mid
# princess_peach__s_castle_theme.mid
# Privation_of_Summons (Extraction).mid
# Protecting_My_Devotion (lossofme_battle).mid
# proto1.mid
# protoman2.mid
# pursuitnes.mid
# Qu.mid
# Queen_of_frogs.mid
# rainbow_cruise_theme.mid
# rainbow_road.mid
# rainy_day.mid
# ralph.mid
# rarewarelogo.mid
# Rebirth_of_Evil_Mist (Invincible).mid
# recorder.mid
# remembering.mid
# reptilerumble.mid
# Retro_Hippie.mid
# ringman.mid
# RoadToTheMakuTree.mid
# ROCK7ST1.MID
# ruins2.mid
# ruins3.mid
# ruins_of_Madain_Sari.mid
# Run.mid
# runawayfive.mid
# SaGaon.mid
# saturnv.mid
# save_game.mid
# Seach_for_the_Princess.mid
# SeasonsGO.mid
# seatown.mid
# secret_library_daguerreo.mid
# shademan.mid
# shademan2.mid
# skirmish_with_the_Silver_Dragons.mid
# skullman.mid
# skullpirates.mid
# slashman.mid
# Slew_of_love_letters.mid
# slot_car_race.mid
# sm3battl.mid
# sm3big.mid
# sm3deser.mid
# sm3grass.mid
# sm3koopa.mid
# sm3ocean.mid
# sm3ow2.mid
# sm3pipe.mid
# sm3undw.mid
# sm3warp.mid
# sm3wd1.mid
# sm3wd3.mid
# smb1-1-1_Remix.mid
# smb1-1-1_Remix2.mid
# smb1-1-1_Remix3.mid
# smb1-1-1_Remix4.mid
# smb1-1-2_Remix.mid
# smb1-1-2_Remix2.mid
# smb1-1up.mid
# smb1-beat_bowser.mid
# smb1-Castle.mid
# smb1-Credits.mid
# smb1-flag.mid
# smb1-star.mid
# smb1-Theme.mid
# smb3_coin_heaven.mid
# smk-battle1.mid
# smk-battle2.mid
# smk-choco_is.mid
# smk-donut_plains.mid
# smk-koopa_beach2.mid
# smk-rr.mid
# smk-theme2.mid
# smk-vanilla_lake.mid
# smkartghostvalley.mid
# smkbowser.mid
# smkkpabeach.mid
# smk_koopabeach.mid
# smk_theme.mid
# smk_vanilla_lake.mid
# smwbow.mid
# smwbow2.mid
# smwcstle.mid
# smwfrst.mid
# smwintro.mid
# smwwat.mid
# smwwater.mid
# smwwaterlevel.mid
# smwwd1.mid
# smwwd2.mid
# smwwin.mid
# smw_level_1.mid
# Snowdkc3.mid
# Snowhead.mid
# snowsnesdk3.mid
# Song_of_Memory.mid
# souless_village_Branbul.mid
# spiralpegasus.mid
# springman.mid
# springman2.mid
# Stage_1-1_(CV4_Rize).mid
# stage_select1.mid
# STAIRWAY.mid
# star.mid
# starman.mid
# start_game.mid
# Steiner_theme.mid
# Stone_tower.mid
# Subrosia.mid
# suburbia.mid
# Super_Castlevania_4_-_Simon.mid
# Super_Castlevania_4_-_The_Library.mid
# swordman.mid
# taamuruins.mid
# tag_barrel.mid
# tall_tower.mid
# tantarus_theme.mid
# templeruins.mid
# tera.mid
# Termina.mid
# termina_bay.mid
# terra_funk.mid
# tetra master.mid
# The3fiends.mid
# THEMEFX.MID
# theme_music.mid
# Theme_of_Simon-KKC.mid
# The_awakening_of_Zelda.mid
# the_city_that_never_sleeps_toleno.mid
# the_dark_messenger.mid
# The_great_sea.mid
# The_king_of_hyrule.mid
# the_k_funk.mid
# the_place_ill_return_to_someday.mid
# The_requiem_of_wind.mid
# the_thing_i_must_protect.mid
# The_violin_of_Makar.mid
# Threed.mid
# title.mid
# title1.mid
# title2.mid
# title3.mid
# title4.mid
# title5.mid
# title6.mid
# title7.mid
# title8.mid
# title9.mid
# title_screen.mid
# Title_screen_2.mid
# Title_screen_3.mid
# toadman.mid
# tomahawkman.mid
# town.mid
# toxic_seahorse.mid
# toxic_seahorse_fowler.mid
# track1.mid
# track2.mid
# treasure_hunt.mid
# triforce1.mid
# triforce2.mid
# triforce3.mid
# troffn_scoffs_room.mid
# troffn_scoffs_room_2.mid
# trophy_tussle.mid
# troupe.mid
# trumpet.mid
# tunnel_rhino.mid
# Twoson.mid
# ukelele_del_chocobo.mid
# UNDERFX.MID
# undermario.mid
# underwater.mid
# underworld_theme.mid
# vamo_alla_flamenco.mid
# vamo_alla_flamenco2.mid
# Vampkill.mid
# Vivi's Theme.mid
# volt_catfish.mid
# wall_of_sacred_beasts.mid
# Waterfalls.mid
# waveman.mid
# waveman2.mid
# win1.mid
# Windfish_ballad.mid
# windman.mid
# windman2.mid
# windman3.mid
# world_2_muda.mid
# world_4_chai1.mid
# world_4_chai2.mid
# X3intro.mid
# X3password.mid
# X3stage_intro.mid
# X3title.mid
# X3weapon.mid
# X5sel2.mid
# X6-Final.mid
# X6_-_Shellfish.mid
# yamatoman.mid
# Youre_not_alone.mid
# youre_not_alone2.mid
# z2cave.mid
# z2house.mid
# z2ow.mid
# z2temple.mid
# z2title.mid
# z2town.mid
# z3castl1.mid
# z3castl2.mid
# z3cave.mid
# z3credit.mid
# z3darkw1.mid
# z3darkw2.mid
# z3ending.mid
# z3fairy.mid
# z3fairy2.mid
# z3intro.mid
# z3lightw.mid
# z3woods.mid
# z64court.mid
# z64deku.mid
# z64epona.mid
# z64fairy.mid
# z64fairy2.mid
# z64fount.mid
# z64geru2.mid
# z64gerud.mid
# z64goron.mid
# z64ice.mid
# z64intro.mid
# z64inwml.mid
# z64jabu.mid
# z64kokri.mid
# z64lab.mid
# z64lnkhs.mid
# z64lon.mid
# z64lostw.mid
# z64lull.mid
# z64lwoo2.mid
# z64main.mid
# z64markt.mid
# z64mast.mid
# z64morn.mid
# z64owl.mid
# z64poe.mid
# z64saria.mid
# z64sheik.mid
# z64shop.mid
# z64temp2.mid
# z64templ.mid
# z64ttime.mid
# z64water.mid
# z64zora.mid
# Zelda-_Windmill_1.mid
# Zelda-_Windmill_2.mid
# z_OofAcrescentisland.mid
# z_OofAcrowndungeon+.mid
# z_OofAinside.mid
# z_OofAMakuroad.mid
# z_OofAmoonlitgrotto.mid
# z_OofAnayru'ssong.mid
# z_OofAtokayhouse.mid
# z_OofSancientruins.mid
# z_OofSdancingdragon.mid
# z_OofShoronvillage.mid
# z_OofSsamasadesert.mid
# z_OofStarmruins.mid

# %%
def get_tracks(note_sequence_notes):
    tracks = [] 
    current_track = []
    current_track_instrument = None
    for note_sequence in note_sequence_notes:
        if not current_track:
            current_track_instrument = note_sequence.program
            current_track.append(note_sequence)
            continue

        if note_sequence.program == current_track_instrument:
            current_track.append(note_sequence)
        else:
            tracks.append(current_track)
            current_track = [note_sequence]
            current_track_instrument = note_sequence.program
    tracks.append(current_track)
    return tracks

# %%
# convert the music note sequences into token sequences
def note_sequence_to_token_sequence(note_sequence):
    token_sequence = []
    token_sequence.append("PIECE_START")
    # for each track in the piece generate a token sequence
    for track in get_tracks(note_sequence.notes):
        token_sequence.append("TRACK_START")
        token_sequence.append(f"INST={track[0].program}")
        # for each bar in the track generate a token sequence
        for bar in range(0, int(note_sequence.total_time / BAR_LENGTH)):
            token_sequence.append("BAR_START")
            current_time = 0
            if track[0].start_time > 0:
                delta = track[0].start_time / NOTE_LENGTH_16TH
                token_sequence.append(f"TIME_DELTA={delta}")
            for note in track:
                if note.start_time > current_time:
                    delta = (note.start_time - current_time) / NOTE_LENGTH_16TH
                    token_sequence.append(f"TIME_DELTA={delta}")
                token_sequence.append(f"NOTE_ON={note.pitch}")
                token_sequence.append(f"NOTE_OFF={note.pitch}")
                current_time = note.end_time
            if current_time < note_sequence.total_time:
                delta = (note_sequence.total_time - current_time) / NOTE_LENGTH_16TH
                token_sequence.append(f"TIME_DELTA={delta}")
            token_sequence.append("BAR_END")
        token_sequence.append("TRACK_END")
    token_sequence.append("PIECE_END")
    return ' '.join(token_sequence)

# %%
dict_["token_sequences"] = [note_sequence_to_token_sequence(note_sequence) for note_sequence in dict_["note_sequences"]]

# %%
from datasets import DatasetDict

train_dict = {"midi_ids": dict_["midi_ids"][0:1200], "token_sequences": dict_["token_sequences"][0:1200]}
valid_dict = {"midi_ids": dict_["midi_ids"][1200:], "token_sequences": dict_["token_sequences"][1200:]}

raw_datasets = DatasetDict(
    {
        "train": train_dict,  # .shuffle().select(range(50000)),
        "valid": valid_dict,  # .shuffle().select(range(500))
    }
)

# %%
raw_datasets
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:222 in   │
# │ catch_format_error                                                                               │
# │                                                                                                  │
# │    219 def catch_format_error(method, self, *args, **kwargs):                                    │
# │    220 │   """show traceback on failed format call"""                                            │
# │    221 │   try:                                                                                  │
# │ ❱  222 │   │   r = method(self, *args, **kwargs)                                                 │
# │    223 │   except NotImplementedError:                                                           │
# │    224 │   │   # don't warn on NotImplementedErrors                                              │
# │    225 │   │   return self._check_return(None, args[0])                                          │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:707 in   │
# │ __call__                                                                                         │
# │                                                                                                  │
# │    704 │   │   │   │   singleton_pprinters=self.singleton_printers,                              │
# │    705 │   │   │   │   type_pprinters=self.type_printers,                                        │
# │    706 │   │   │   │   deferred_pprinters=self.deferred_printers)                                │
# │ ❱  707 │   │   │   printer.pretty(obj)                                                           │
# │    708 │   │   │   printer.flush()                                                               │
# │    709 │   │   │   return stream.getvalue()                                                      │
# │    710                                                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\IPython\lib\pretty.py:410 in pretty │
# │                                                                                                  │
# │   407 │   │   │   │   │   │   │   │   return meth(obj, self, cycle)                              │
# │   408 │   │   │   │   │   │   if cls is not object \                                             │
# │   409 │   │   │   │   │   │   │   │   and callable(cls.__dict__.get('__repr__')):                │
# │ ❱ 410 │   │   │   │   │   │   │   return _repr_pprint(obj, self, cycle)                          │
# │   411 │   │   │                                                                                  │
# │   412 │   │   │   return _default_pprint(obj, self, cycle)                                       │
# │   413 │   │   finally:                                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\IPython\lib\pretty.py:778 in        │
# │ _repr_pprint                                                                                     │
# │                                                                                                  │
# │   775 def _repr_pprint(obj, p, cycle):                                                           │
# │   776 │   """A pprint that just redirects to the normal repr function."""                        │
# │   777 │   # Find newlines and replace them with p.break_()                                       │
# │ ❱ 778 │   output = repr(obj)                                                                     │
# │   779 │   lines = output.splitlines()                                                            │
# │   780 │   with p.group():                                                                        │
# │   781 │   │   for idx, output_line in enumerate(lines):                                          │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\dataset_dict.py │
# │ :245 in __repr__                                                                                 │
# │                                                                                                  │
# │    242 │   │   return {k: dataset.cleanup_cache_files() for k, dataset in self.items()}          │
# │    243 │                                                                                         │
# │    244 │   def __repr__(self):                                                                   │
# │ ❱  245 │   │   repr = "\n".join([f"{k}: {v}" for k, v in self.items()])                          │
# │    246 │   │   repr = re.sub(r"^", " " * 4, repr, 0, re.M)                                       │
# │    247 │   │   return f"DatasetDict({{\n{repr}\n}})"                                             │
# │    248                                                                                           │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\dataset_dict.py │
# │ :245 in <listcomp>                                                                               │
# │                                                                                                  │
# │    242 │   │   return {k: dataset.cleanup_cache_files() for k, dataset in self.items()}          │
# │    243 │                                                                                         │
# │    244 │   def __repr__(self):                                                                   │
# │ ❱  245 │   │   repr = "\n".join([f"{k}: {v}" for k, v in self.items()])                          │
# │    246 │   │   repr = re.sub(r"^", " " * 4, repr, 0, re.M)                                       │
# │    247 │   │   return f"DatasetDict({{\n{repr}\n}})"                                             │
# │    248                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# MemoryError

# %%
context_length = 128

def tokenize(element):
    outputs = tokenizer(
        element["content"],
        truncation=True,
        max_length=context_length,
        return_overflowing_tokens=True,
        return_length=True,
    )
    input_batch = []
    for length, input_ids in zip(outputs["length"], outputs["input_ids"]):
        if length == context_length:
            input_batch.append(input_ids)
    return {"input_ids": input_batch}


tokenized_datasets = raw_datasets.map(
    tokenize, batched=True, remove_columns=raw_datasets["train"].column_names
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:19                                                                                   │
# │                                                                                                  │
# │   16                                                                                             │
# │   17                                                                                             │
# │   18 tokenized_datasets = raw_datasets.map(                                                      │
# │ ❱ 19 │   tokenize, batched=True, remove_columns=raw_datasets["train"].column_names               │
# │   20 )                                                                                           │
# │   21                                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'dict' object has no attribute 'column_names'

# %%
from transformers import DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(tokenizer, mlm=False)

# %%
from transformers import Trainer, TrainingArguments

args = TrainingArguments(
    output_dir="codeparrot-ds",
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    evaluation_strategy="steps",
    eval_steps=5_000,
    logging_steps=5_000,
    gradient_accumulation_steps=8,
    num_train_epochs=1,
    weight_decay=0.1,
    warmup_steps=1_000,
    lr_scheduler_type="cosine",
    learning_rate=5e-4,
    save_steps=5_000,
    fp16=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    tokenizer=tokenizer,
    args=args,
    data_collator=data_collator,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["valid"],
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:26                                                                                   │
# │                                                                                                  │
# │   23 │   tokenizer=tokenizer,                                                                    │
# │   24 │   args=args,                                                                              │
# │   25 │   data_collator=data_collator,                                                            │
# │ ❱ 26 │   train_dataset=tokenized_datasets["train"],                                              │
# │   27 │   eval_dataset=tokenized_datasets["valid"],                                               │
# │   28 )                                                                                           │
# │   29                                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'tokenized_datasets' is not defined

# %%
generated_sequence = "PIECE_START"

# %%
# Encode the conditioning tokens.
input_ids = tokenizer.encode("PIECE_START", return_tensors="pt")
#print(input_ids)

# Generate more tokens.
eos_token_id = tokenizer.encode("PIECE_END")[0]
temperature = 1.0
generated_ids = model.generate(
    input_ids, 
    max_length=2048,
    do_sample=True,
    temperature=temperature,
    eos_token_id=eos_token_id,
)
generated_sequence = tokenizer.decode(generated_ids[0])
print(generated_sequence)

note_sequence = token_sequence_to_note_sequence(generated_sequence)

synth = note_seq.fluidsynth
note_seq.note_sequence_to_midi_file(note_sequence, "output.mid")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:8                                                                                    │
# │                                                                                                  │
# │    5 # Generate more tokens.                                                                     │
# │    6 eos_token_id = tokenizer.encode("PIECE_END")[0]                                             │
# │    7 temperature = 1.0                                                                           │
# │ ❱  8 generated_ids = model.generate(                                                             │
# │    9 │   input_ids,                                                                              │
# │   10 │   max_length=2048,                                                                        │
# │   11 │   do_sample=True,                                                                         │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib. │
# │ py:115 in decorate_context                                                                       │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\generation\utils.py:14 │
# │ 85 in generate                                                                                   │
# │                                                                                                  │
# │   1482 │   │   │   )                                                                             │
# │   1483 │   │   │                                                                                 │
# │   1484 │   │   │   # 13. run sample                                                              │
# │ ❱ 1485 │   │   │   return self.sample(                                                           │
# │   1486 │   │   │   │   input_ids,                                                                │
# │   1487 │   │   │   │   logits_processor=logits_processor,                                        │
# │   1488 │   │   │   │   logits_warper=logits_warper,                                              │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\generation\utils.py:25 │
# │ 24 in sample                                                                                     │
# │                                                                                                  │
# │   2521 │   │   │   model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)  │
# │   2522 │   │   │                                                                                 │
# │   2523 │   │   │   # forward pass to get next token                                              │
# │ ❱ 2524 │   │   │   outputs = self(                                                               │
# │   2525 │   │   │   │   **model_inputs,                                                           │
# │   2526 │   │   │   │   return_dict=True,                                                         │
# │   2527 │   │   │   │   output_attentions=output_attentions,                                      │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module. │
# │ py:1501 in _call_impl                                                                            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\models\gpt2\modeling_g │
# │ pt2.py:1075 in forward                                                                           │
# │                                                                                                  │
# │   1072 │   │   """                                                                               │
# │   1073 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return  │
# │   1074 │   │                                                                                     │
# │ ❱ 1075 │   │   transformer_outputs = self.transformer(                                           │
# │   1076 │   │   │   input_ids,                                                                    │
# │   1077 │   │   │   past_key_values=past_key_values,                                              │
# │   1078 │   │   │   attention_mask=attention_mask,                                                │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module. │
# │ py:1501 in _call_impl                                                                            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\models\gpt2\modeling_g │
# │ pt2.py:899 in forward                                                                            │
# │                                                                                                  │
# │    896 │   │   │   │   │   encoder_attention_mask,                                               │
# │    897 │   │   │   │   )                                                                         │
# │    898 │   │   │   else:                                                                         │
# │ ❱  899 │   │   │   │   outputs = block(                                                          │
# │    900 │   │   │   │   │   hidden_states,                                                        │
# │    901 │   │   │   │   │   layer_past=layer_past,                                                │
# │    902 │   │   │   │   │   attention_mask=attention_mask,                                        │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module. │
# │ py:1501 in _call_impl                                                                            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\models\gpt2\modeling_g │
# │ pt2.py:426 in forward                                                                            │
# │                                                                                                  │
# │    423 │   │                                                                                     │
# │    424 │   │   residual = hidden_states                                                          │
# │    425 │   │   hidden_states = self.ln_2(hidden_states)                                          │
# │ ❱  426 │   │   feed_forward_hidden_states = self.mlp(hidden_states)                              │
# │    427 │   │   # residual connection                                                             │
# │    428 │   │   hidden_states = residual + feed_forward_hidden_states                             │
# │    429                                                                                           │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module. │
# │ py:1501 in _call_impl                                                                            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\models\gpt2\modeling_g │
# │ pt2.py:353 in forward                                                                            │
# │                                                                                                  │
# │    350 │   │   self.dropout = nn.Dropout(config.resid_pdrop)                                     │
# │    351 │                                                                                         │
# │    352 │   def forward(self, hidden_states: Optional[Tuple[torch.FloatTensor]]) -> torch.FloatT  │
# │ ❱  353 │   │   hidden_states = self.c_fc(hidden_states)                                          │
# │    354 │   │   hidden_states = self.act(hidden_states)                                           │
# │    355 │   │   hidden_states = self.c_proj(hidden_states)                                        │
# │    356 │   │   hidden_states = self.dropout(hidden_states)                                       │
# │                                                                                                  │
# │ c:\Users\nrtc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module. │
# │ py:1501 in _call_impl                                                                            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\nrtc\AppData\Roaming\Python\Python311\site-packages\transformers\pytorch_utils.py:102   │
# │ in forward                                                                                       │
# │                                                                                                  │
# │    99 │                                                                                          │
# │   100 │   def forward(self, x):                                                                  │
# │   101 │   │   size_out = x.size()[:-1] + (self.nf,)                                              │
# │ ❱ 102 │   │   x = torch.addmm(self.bias, x.view(-1, x.size(-1)), self.weight)                    │
# │   103 │   │   x = x.view(size_out)                                                               │
# │   104 │   │   return x                                                                           │
# │   105                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
